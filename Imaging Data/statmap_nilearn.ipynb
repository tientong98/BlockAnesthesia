# %%
# %matplotlib inline
from nilearn import plotting
from nilearn import image
# Out:
# /Shared/pinc/sharedopt/apps/anaconda3/Linux/x86_64/2019.07/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
stat_map_img = "/Shared/rblock_mr/derivatives/subject_glm/sternberg/PTvsNT/sub-8006.gfeat/cope1.feat/thresh_zstat_combined.nii.gz"
bg_img = "/Shared/pinc/sharedopt/apps/fsl/Linux/x86_64/5.0.8_multicore/data/standard/MNI152_T1_2mm_brain.nii.gz"
plotting.plot_stat_map(stat_map_img, bg_img, cut_coords=15, 
                       output_file=None, display_mode='x', colorbar=True, figure=None, 
                       axes=None, title=None, threshold=1e-06, annotate=True, draw_cross=True, 
                       black_bg='auto')

# %%
sternlist = [
    "/Shared/rblock_mr/derivatives/subject_glm/sternberg/PTvsNT/sub-8006.gfeat/cope1.feat/thresh_zstat_combined.nii.gz",
    "/Shared/rblock_mr/derivatives/subject_glm/sternberg/PTvsNT/sub-8013.gfeat/cope1.feat/thresh_zstat_combined.nii.gz"
]

bg_img = "/Shared/pinc/sharedopt/apps/fsl/Linux/x86_64/5.0.8_multicore/data/standard/MNI152_T1_2mm_brain.nii.gz"

for x in range(0, 2):
    plotting.plot_stat_map(sternlist[x], bg_img, cut_coords=15, 
                       output_file=None, display_mode='x', colorbar=True, figure=None, 
                       axes=None, title=None, threshold=1e-06, annotate=True, draw_cross=True, 
                       black_bg='auto')
